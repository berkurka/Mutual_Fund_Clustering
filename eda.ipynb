# %%
import pandas as pd

# %%
df = pd.read_excel('./Selected Funds.xlsx')

# %%
df.shape
# Out:
# (4091, 58)

# %%
df.head()
# Out:
#                                              Name  \
# 0                                             NaN
# 1                                             NaN
# 2  051 SPA VISTA MULTIESTRATÉGIA FIC MULTIMERCADO
# 3               14 BIS AGRESSIVO FIC MULTIMERCADO
# 4             14 BIS CONSERVADOR FIC MULTIMERCADO
#
#                       Administrator             Benchmark Closing Date  \
# 0                               NaN                   NaN          NaT
# 1                               NaN                   NaN          NaT
# 2  BTG Pactual Serviços Financeiros        Non-classified          NaT
# 3   BNY Mellon Serviços Financeiros  CDI (Interbank Rate)   2013-02-13
# 4   BNY Mellon Serviços Financeiros  CDI (Interbank Rate)   2012-08-15
#
#                  CNPJ      Current Situation          Custodian CVM Category  \
# 0                 NaN                    NaN                NaN          NaN
# 1                 NaN                    NaN                NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4091 entries, 0 to 4090
# Data columns (total 58 columns):
# Name                                  4087 non-null object
# Administrator                         4079 non-null object
# Benchmark                             4079 non-null object
# Closing Date                          1803 non-null datetime64[ns]
# CNPJ                                  4079 non-null object
# Current Situation                     4079 non-null object
# Custodian                             4079 non-null object
# CVM Category                          4079 non-null object
# Director                              4079 non-null object
# Entidade de Previdência 3922_US       4079 non-null object
# Entidade de Previdência 4444_US       4079 non-null object
# Entidade de Previdência 4661_US       4079 non-null object
# Exclusive Fund                        4079 non-null object
# Fee Notes                             4079 non-null object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Administrator', 'Benchmark', 'Closing Date', 'CNPJ',
#        'Current Situation', 'Custodian', 'CVM Category', 'Director',
#        'Entidade de Previdência 3922_US', 'Entidade de Previdência 4444_US',
#        'Entidade de Previdência 4661_US', 'Exclusive Fund', 'Fee Notes',
#        'Feeder', 'Financial Management Fee', 'Foreign Investment Anbima',
#        'Fund's Length', 'Headquarter (State)', 'Headquarters (City)',
#        'Headquarters (Neighborhood)', 'Investment NAV', 'Join Date',
#        'Legal Classification', 'Leveraged Anbima', 'Management Company',
#        'Management Company Name', 'Management Fee', 'Management Fee (Maximum)',
#        'Management Fee Charging Frequency', 'Management Fee Provision',
#        'Management Fee Type', 'Master', 'Maximum Balance', 'Minimum Balance',
#        'Minimum Investment', 'Minimum Movement', 'Minimum Redemption',
#        'Open to Investments', 'Performance Fee',
# ...
